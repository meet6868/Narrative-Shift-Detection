# %% [markdown]
# # 📊 CSV Data Explorer
# ## Load, Explore, and Analyze CSV Files
#
# **Features:**
# - ✅ Load any CSV file
# - ✅ Display column names and data types
# - ✅ Show basic statistics
# - ✅ Display sample data (first/last rows)
# - ✅ Check for missing values
# - ✅ Display dataset shape and memory usage
#
# ---

# %% [markdown]
# ## Step 1: Import Required Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
from pathlib import Path
import warnings

warnings.filterwarnings('ignore')

print("✅ Libraries imported successfully!")
print(f"   Pandas version: {pd.__version__}")
print(f"   NumPy version: {np.__version__}")
# Out:
# ✅ Libraries imported successfully!
#    Pandas version: 2.3.3
#    NumPy version: 2.3.5

# %% [markdown]
# ## Step 2: Set File Path
#
# **Instructions:**
# - Update the `CSV_FILE_PATH` variable with your CSV file path
# - Can be absolute path: `/home/user/data/file.csv`
# - Or relative path: `../DATA/file.csv`

# %%
# ============================================================================
# SET YOUR CSV FILE PATH HERE
# ============================================================================

# Example paths (uncomment and modify one):
# CSV_FILE_PATH = '../DATA/CNN_Articels_clean.csv'
# CSV_FILE_PATH = '../Processed_Data/ALL_Combined_Data.csv'
# CSV_FILE_PATH = '/home/hp/SEM2/INLP/Naretve_Shift/DATA/Covid_News.csv'

# CSV_FILE_PATH = '../DATA/CNN_Articels_clean.csv'  # UPDATE THIS!

# CSV_FILE_PATH = '../DATA/CNN_Articels_clean.csv'  # UPDATE THIS!
CSV_FILE_PATH = '../Processed_Data/Topic_Wise/Health.csv'  # UPDATE THIS!
# Convert to Path object
csv_path = Path(CSV_FILE_PATH)

# Verify file exists
if csv_path.exists():
    file_size_mb = csv_path.stat().st_size / (1024 * 1024)
    print(f"✅ File found: {csv_path.name}")
    print(f"   Path: {csv_path.absolute()}")
    print(f"   Size: {file_size_mb:.2f} MB")
else:
    print(f"❌ ERROR: File not found at {csv_path.absolute()}")
    print(f"\n💡 Please update the CSV_FILE_PATH variable with the correct path")
# Out:
# ✅ File found: Health.csv
#    Path: /home/hp/SEM2/INLP/Naretve_Shift/Pre_Processin/../Processed_Data/Topic_Wise/Health.csv
#    Size: 1610.51 MB

# %% [markdown]
# ## Step 3: Load CSV File

# %%
# Load CSV file
print("🔄 Loading CSV file...")

try:
    df = pd.read_csv(csv_path)
    print(f"✅ CSV file loaded successfully!")
    print(f"\n📊 Dataset Shape: {df.shape[0]:,} rows × {df.shape[1]} columns")
except Exception as e:
    print(f"❌ Error loading file: {e}")
    df = None
# Out:
# 🔄 Loading CSV file...
# ✅ CSV file loaded successfully!
#
# 📊 Dataset Shape: 171,980 rows × 8 columns

# %% [markdown]
# ## Step 4: Display Column Information

# %%
if df is not None:
    print("=" * 80)
    print("📋 COLUMN INFORMATION")
    print("=" * 80)
    
    print(f"\n🔢 Total Columns: {len(df.columns)}\n")
    
    # Create column info dataframe
    col_info = pd.DataFrame({
        'Column Name': df.columns,
        'Data Type': df.dtypes.values,
        'Non-Null Count': df.count().values,
        'Null Count': df.isnull().sum().values,
        'Null %': (df.isnull().sum() / len(df) * 100).round(2).values
    })
    
    print(col_info.to_string(index=False))
    print("\n" + "=" * 80)
# Out:
# ================================================================================
# 📋 COLUMN INFORMATION
# ================================================================================
#
# 🔢 Total Columns: 8
#
#   Column Name Data Type  Non-Null Count  Null Count  Null %
#          date    object          171980           0     0.0
#  w3_embedding    object          171980           0     0.0
# main_sentence    object          171980           0     0.0
#           War   float64          171980           0     0.0
#        Health   float64          171980           0     0.0
#    Technology   float64          171980           0     0.0
#       Climate   float64          171980           0     0.0
#     Economics   float64          171980           0     0.0
#
# ================================================================================

# %% [markdown]
# ## Step 5: Display Sample Data - First Rows

# %%
if df is not None:
    print("=" * 80)
    print("📄 FIRST 5 ROWS (HEAD)")
    print("=" * 80)
    print()
    
    # Set pandas display options for full width
    pd.set_option('display.max_colwidth', None)  # Show full column width
    pd.set_option('display.width', None)  # Auto-detect display width
    
    display(df.head(25)[['date','War','Health','Climate','Economics','Technology','main_sentence']])
# Out:
# ================================================================================
# 📄 FIRST 5 ROWS (HEAD)
# ================================================================================
#                    date       War    Health   Climate  Economics  Technology  \
# 0   2011-09-06 21:38:21 -0.006416  0.307802  0.048885   0.071733    0.042522
# 1   2011-09-06 21:38:21 -0.001921  0.311719  0.057567   0.087653    0.055862
# 2   2011-09-06 21:38:21  0.010214  0.304212  0.044431   0.086640    0.043822
# 3   2011-09-06 21:38:21  0.027061  0.320981  0.027376   0.092762    0.079373
# 4   2011-09-06 21:38:21  0.014797  0.307903  0.026376   0.129430    0.128450
# 5   2011-10-01 13:16:50  0.186735  0.322363  0.184972   0.282463    0.236345
# 6   2011-10-01 13:16:50  0.198276  0.325974  0.199461   0.284246    0.241193
# 7   2011-10-01 13:16:50  0.222696  0.363912  0.235399   0.292775    0.268480
# 8   2011-10-05 13:44:27  0.180874  0.306910  0.176730   0.325088    0.225466
# 9   2011-10-14 15:46:44  0.151339  0.345836  0.094911   0.099386    0.087178
# 10  2011-10-14 18:03:13  0.274700  0.337259  0.313630   0.382570    0.360288
# 11  2011-10-14 18:03:13  0.280194  0.321380  0.336748   0.388445    0.322084
# 12  2011-10-14 18:03:13  0.249924  0.354733  0.340325   0.412634    0.327979
# 13  2011-10-14 18:03:13  0.211221  0.300677  0.227839   0.321433    0.286375
# 14  2011-10-14 18:03:13  0.237054  0.352563  0.286841   0.374164    0.310028
# 15  2011-10-17 21:41:17  0.221379  0.343691  0.265758   0.350973    0.334461
# 16  2011-10-17 21:41:17  0.167258  0.310403  0.157428   0.211450    0.252837
# 17  2011-10-17 21:41:17  0.178631  0.300440  0.158551   0.168946    0.264482
# 18  2011-10-17 21:41:17  0.187818  0.416984  0.172179   0.153227    0.228744
# 19  2011-10-18 05:47:01  0.205829  0.300632  0.294199   0.419911    0.307162
# 20  2011-10-18 05:47:01  0.292505  0.356897  0.333431   0.432663    0.415449
# 21  2011-10-18 05:47:01  0.313030  0.395706  0.349964   0.450878    0.435939
# 22  2011-10-18 05:47:01  0.303740  0.389111  0.351085   0.518701    0.465584
# 23  2011-10-26 18:18:36  0.271864  0.304571  0.461490   0.265329    0.141916
# 24  2011-10-26 18:18:36  0.281022  0.338799  0.380336   0.266337    0.172663
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          main_sentence
# 0   Story highlightsWomen who averaged 3 to 15 alcoholic drinks per week had higher odds of being healthyThe findings don't necessarily apply to men or to nonwhite womenExperiments have shown that moderate alcohol intake can reduce inflammationMiddle-aged women who drink alcohol in moderation have a better chance than nondrinkers of staying healthy as they age, especially if they spread out their consumption over most days of the week, a new study from Harvard researchers suggests.
# 1                                                                                                                                                                                                                           Compared with teetotalers, those who averaged roughly three to 15 alcoholic drinks per week in their late 50s had up to 28% higher odds of being free from chronic illness, physical disability, mental health problems, and cognitive decline at age 70, the study found.
# 2                                                                                                                                                                                     Sun and his colleagues took into account more than a dozen health and demographic factors that could influence both drinking and aging (such as diet, smoking, educational attainment, and family history of disease), but it's still possible that the moderate drinkers differed in key ways from their peers.
# 3                                                                                                                                                                                                                                                                    People who drink in moderation "look systematically different than those who...either binge drink or don't drink," says Karlamangla, who has researched alcohol consumption and disability but was not involved in the new study.
# 4                                                                                                                                                                                                                                                                                                                                                          They compared the women's self-reported drinking in middle age -- when the women were 58, on average -- with their health status at age 70.
# 5                                                                                                                                                          After all, many of them can use the illegal markets available in their immediate surroundings," the press release says.The statement does not give a date for the implementation of the new measures.CNN's calls to the Dutch justice ministry were not immediately returned.But Josemans says cannabis supply is not only a Dutch problem.
# 6                                                                                                                                                                                                                                                                                                            "This is also the responsibility of the other European governments; nobody is taking responsibility for those millions of customers who want to buy cannabis for their own use," he said.
# 7                                                                                                                                                                                                                                                                                                                                                                                       "It is time to get their heads out of the sand to get a decent drugs policy in place to address this problem."
# 8                                                                                                                                                                                                                                                                                                                                                             Earlier this week the government announced it would retire 30,000 people in a bid to cut 300 million euros in operating costs next year.
# 9                                                                                                                                                                                                                                                                                                                                                                                                   But it stems from a nonspoken history that lives in our communities past and present," Mirza said.
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                              I think we'll get acclimated to it," Jeb Lessley said.
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                 Jenkins overheard the conversation and interrupted.
# 12                                                                                                                                                                                                                                                                                                                                 She'd already made it clear to a reporter that she thinks the effects of HB56 -- on food prices, on the tax base, on many industries' labor pools -- will run deep.
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                            "You think it's just affecting farmers?"
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     she challenged.
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                            '"Is the track big enough to accommodate 34 racing cars?
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                            There are always improvements able to be made," he said.
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                              "Modern technology, modern materials, it is available.
# 18                                                                                                                                                                                                                                                                                                                                                                    It's just a question of being able to think out of the box and have preventative medicine rather than just corrective medicine."
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                        "The system needs to change.
# 20                                                                                                                                                                                                                                                                                                                                                                                          We need to focus not on big profits, not on the headline figures, but on what they mean to people's lives.
# 21                                                                                                                                                                                                                                                                                                                                                                      "I work in schools, and the kids are terrified -- they really don't like the generation above, they think 'You've screwed us.'
# 22                                                                                                                                                                                                                                                                                                                                                                                                     They are left with no opportunities, but they are the ones who are having to pick up the costs.
# 23                                                                                                                                                                                                                                                                                                 Events like Hurricane Katrina, says the report, highlight how even the economically strongest countries with a large adaptive capacity can find themselves extremely vulnerable to climatic events.
# 24                                                                                                                                                                                                                                                                                                                                                                                                 The report is released just days before the world's population is projected to reach seven billion.

# %% [markdown]
# ## Step 6: Display Sample Data - Last Rows

# %%
if df is not None:
    print("=" * 80)
    print("📄 LAST 5 ROWS (TAIL)")
    print("=" * 80)
    print()
    display(df.tail())

# %% [markdown]
# ## Step 7: Display Random Sample

# %%
if df is not None:
    print("=" * 80)
    print("🎲 RANDOM SAMPLE (5 rows)")
    print("=" * 80)
    print()
    display(df.sample(min(5, len(df))))

# %% [markdown]
# ## Step 8: Basic Statistics for Numerical Columns

# %%
if df is not None:
    print("=" * 80)
    print("📈 NUMERICAL STATISTICS")
    print("=" * 80)
    print()
    
    numerical_cols = df.select_dtypes(include=[np.number]).columns
    
    if len(numerical_cols) > 0:
        display(df[numerical_cols].describe())
    else:
        print("ℹ️  No numerical columns found")

# %% [markdown]
# ## Step 9: Statistics for Text/Object Columns

# %%
if df is not None:
    print("=" * 80)
    print("📝 TEXT/OBJECT COLUMN STATISTICS")
    print("=" * 80)
    print()
    
    object_cols = df.select_dtypes(include=['object']).columns
    
    if len(object_cols) > 0:
        for col in object_cols:
            print(f"\n🔹 Column: {col}")
            print(f"   Unique values: {df[col].nunique():,}")
            print(f"   Most common: {df[col].mode().iloc[0] if len(df[col].mode()) > 0 else 'N/A'}")
            print(f"   Sample values: {list(df[col].dropna().unique()[:3])}")
    else:
        print("ℹ️  No text/object columns found")

# %% [markdown]
# ## Step 10: Missing Values Analysis

# %%
if df is not None:
    print("=" * 80)
    print("🔍 MISSING VALUES ANALYSIS")
    print("=" * 80)
    print()
    
    missing_data = pd.DataFrame({
        'Column': df.columns,
        'Missing Count': df.isnull().sum().values,
        'Missing %': (df.isnull().sum() / len(df) * 100).round(2).values,
        'Data Type': df.dtypes.values
    })
    
    # Sort by missing percentage (descending)
    missing_data = missing_data.sort_values('Missing %', ascending=False)
    
    print(missing_data.to_string(index=False))
    
    total_missing = df.isnull().sum().sum()
    total_cells = df.shape[0] * df.shape[1]
    missing_pct = (total_missing / total_cells * 100)
    
    print(f"\n📊 Overall Missing Data:")
    print(f"   Total missing cells: {total_missing:,} out of {total_cells:,} ({missing_pct:.2f}%)")

# %% [markdown]
# ## Step 11: Memory Usage

# %%
if df is not None:
    print("=" * 80)
    print("💾 MEMORY USAGE")
    print("=" * 80)
    print()
    
    memory_usage = df.memory_usage(deep=True)
    total_memory_mb = memory_usage.sum() / (1024 * 1024)
    
    print(f"Total memory usage: {total_memory_mb:.2f} MB\n")
    
    # Top memory consuming columns
    memory_by_col = memory_usage.sort_values(ascending=False)
    print("Top 10 columns by memory usage:")
    for col, mem in memory_by_col.head(10).items():
        if col != 'Index':
            print(f"   {col}: {mem / (1024 * 1024):.2f} MB")

# %% [markdown]
# ## Step 12: Complete Dataset Info Summary

# %%
if df is not None:
    print("=" * 80)
    print("📊 COMPLETE DATASET INFORMATION")
    print("=" * 80)
    print()
    
    df.info()

# %% [markdown]
# ## Step 13: Export Summary Report (Optional)

# %%
if df is not None:
    # Create summary report
    report = {
        'File Name': csv_path.name,
        'File Path': str(csv_path.absolute()),
        'Total Rows': df.shape[0],
        'Total Columns': df.shape[1],
        'Memory Usage (MB)': f"{df.memory_usage(deep=True).sum() / (1024 * 1024):.2f}",
        'Total Missing Values': df.isnull().sum().sum(),
        'Missing Percentage': f"{(df.isnull().sum().sum() / (df.shape[0] * df.shape[1]) * 100):.2f}%",
        'Numerical Columns': len(df.select_dtypes(include=[np.number]).columns),
        'Text Columns': len(df.select_dtypes(include=['object']).columns),
        'Datetime Columns': len(df.select_dtypes(include=['datetime']).columns)
    }
    
    print("=" * 80)
    print("📋 SUMMARY REPORT")
    print("=" * 80)
    print()
    
    for key, value in report.items():
        print(f"{key:.<40} {value}")
    
    print("\n" + "=" * 80)
    print("✅ CSV exploration complete!")
    print("=" * 80)

# %% [markdown]
# ## Step 14: Custom Column Analysis (Optional)
#
# Analyze specific columns in detail

# %%
# Uncomment and modify to analyze specific columns

# COLUMN_TO_ANALYZE = 'Article'  # Change this to your column name

# if df is not None and COLUMN_TO_ANALYZE in df.columns:
#     print(f"=" * 80)
#     print(f"🔍 DETAILED ANALYSIS: {COLUMN_TO_ANALYZE}")
#     print(f"=" * 80)
#     print()
#     
#     print(f"Data Type: {df[COLUMN_TO_ANALYZE].dtype}")
#     print(f"Total Values: {len(df[COLUMN_TO_ANALYZE]):,}")
#     print(f"Unique Values: {df[COLUMN_TO_ANALYZE].nunique():,}")
#     print(f"Missing Values: {df[COLUMN_TO_ANALYZE].isnull().sum():,}")
#     print(f"Missing %: {(df[COLUMN_TO_ANALYZE].isnull().sum() / len(df) * 100):.2f}%")
#     
#     if df[COLUMN_TO_ANALYZE].dtype == 'object':
#         print(f"\nString Length Statistics:")
#         lengths = df[COLUMN_TO_ANALYZE].dropna().astype(str).str.len()
#         print(f"   Min length: {lengths.min()}")
#         print(f"   Max length: {lengths.max()}")
#         print(f"   Mean length: {lengths.mean():.2f}")
#         print(f"   Median length: {lengths.median():.0f}")
#     
#     print(f"\nTop 10 Most Frequent Values:")
#     print(df[COLUMN_TO_ANALYZE].value_counts().head(10))

print("💡 Uncomment and modify the code above to analyze specific columns")
